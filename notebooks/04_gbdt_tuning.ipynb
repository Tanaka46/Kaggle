# %% [markdown]
# # 勾配ブースティング系モデルのチューニング
#
# LightGBM/XGBoost/CatBoost + Optuna

# %% [markdown]
# 参考: [jek1wantaufik/buddy (ScikitLearn/house)](https://www.kaggle.com/models/jek1wantaufik/buddy/ScikitLearn/house) — GradientBoostingRegressor + 対数変換ターゲットのパイプライン構成を踏まえ、まずLightGBMで勾配ブースティング系のCVスコアを確認する。

# %%
import sys
import datetime as dt

import pandas as pd

sys.path.append("..")
from src.models.train import train

# %%
lightgbm_score = train("../configs/lightgbm.yaml")
lightgbm_score
# Out:
# C:\work\Kaggle\住宅価格 - 高度な回帰分析手法\.venv\Lib\site-packages\lightgbm\sklearn.py:1106: LGBMDeprecationWarning: The argument 'eval_set' is deprecated, use 'eval_X' and 'eval_y' instead.
#   eval_set = _validate_eval_set_Xy(eval_set=eval_set, eval_X=eval_X, eval_y=eval_y)
# [LightGBM] [Warning] min_data_in_leaf is set=20, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=20
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] lambda_l1 is set=0.0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0
# [LightGBM] [Warning] lambda_l2 is set=0.0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# ...

# %% [markdown]
# ## 実験ログへの記録

# %%
log_path = "../reports/experiments.csv"
today = dt.date.today().isoformat()
row = pd.DataFrame([{
    "date": today, "method": "lightgbm", "config": "configs/lightgbm.yaml",
    "cv_rmse": lightgbm_score, "lb_score": "", "submission_file": "",
    "notes": "GBDT baseline (ref: jek1wantaufik/buddy ScikitLearn/house)",
}])
row.to_csv(log_path, mode="a", header=False, index=False)
pd.read_csv(log_path)
# Out:
#          date    method                 config   cv_rmse  lb_score  \
# 0  2026-07-19     ridge     configs/ridge.yaml  0.123595       NaN
# 1  2026-07-19     lasso     configs/lasso.yaml  0.120268       NaN
# 2  2026-07-19     ridge     configs/ridge.yaml  0.123595       NaN
# 3  2026-07-19     lasso     configs/lasso.yaml  0.120268   0.13287
# 4  2026-07-19  lightgbm  configs/lightgbm.yaml  0.121929       NaN
# 5  2026-07-19  lightgbm  configs/lightgbm.yaml  0.121034       NaN
#
#                                submission_file  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3  submissions/submission_lasso_2026-07-19.csv
# 4                                          NaN
# 5                                          NaN
#
#                                                notes
# 0                                           baseline
# ...
